# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.colors as mcol

# %%
import math
cm1 = mcol.LinearSegmentedColormap.from_list("MyCmapName",["r","b"])

scores_1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_test_highest_reward.csv").squeeze()
ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores_1, zorder=1)
plot = plt.scatter(c, scores_1, s= 50, c = scores_1, cmap='rainbow_r')
plt.colorbar(plot)
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores_1), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Open Door using PPO')

plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/234176421.py:10: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(plot)

# %%
import math
scores = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/REINFORCE_test_highest_rewards.csv").squeeze()

ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores, zorder=1)
plot = plt.scatter(c, scores, s= 50, c = scores, cmap='rainbow_r', vmin=0, vmax=10)
cbar = plt.colorbar(plot)
cbar.set_ticks([0, 2, 4, 6, 8, 10])
cbar.set_ticklabels(['0', '2', '4', '6', '8', '10'])
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Open Door using REINFORCE')
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/2428298010.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cbar = plt.colorbar(plot)

# %% [markdown]
# # Test Scores

# %%
import pandas as pd
import matplotlib.pyplot as plt

scores = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/Drill/Step_1/PPO_test_highest_reward.csv").squeeze()

ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores, zorder=1)
plot = plt.scatter(c, scores, s= 50, c = scores, cmap='rainbow_r')
plt.colorbar(plot)
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Drill Step 1')
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/1180517202.py:11: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(plot)

# %%
scores = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/Drill/Step_3/PPO_test_highest_reward.csv").squeeze()

ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores, zorder=1)
plot = plt.scatter(c, scores, s= 50, c = scores, cmap='rainbow_r')
plt.colorbar(plot)
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Drill Step 2')
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/2640248087.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(plot)

# %%
scores = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/Wrench/Step_1/PPO_test_highest_reward.csv").squeeze()

ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores, zorder=1)
plot = plt.scatter(c, scores, s= 50, c = scores, cmap='rainbow_r')
plt.colorbar(plot)
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Wrench Step 1')
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/240143111.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(plot)

# %%
scores = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/Wrench/Step_2/PPO_test_highest_reward.csv").squeeze()

ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores, zorder=1)
plot = plt.scatter(c, scores, s= 50, c = scores, cmap='rainbow_r')
plt.colorbar(plot)
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Wrench Step 2')
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/2304018750.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(plot)

# %%
scores = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/Pull_Out/PPO_test_highest_reward.csv")[:10].squeeze()

ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores, zorder=1)
plot = plt.scatter(c, scores, s= 50, c = scores, cmap='rainbow_r')
plt.colorbar(plot)
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Pull Out')
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/1247877729.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(plot)

# %%
scores = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/Hand_Off/PPO_test_highest_reward.csv").squeeze()

ax = plt.axes()
ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores, zorder=1)
plot = plt.scatter(c, scores, s= 50, c = scores, cmap='rainbow_r')
plt.colorbar(plot)
plt.grid(True, 'both')
plt.axhline(y=np.nanmean(scores), color='red', linestyle='--')
plt.ylim((-1,11))
plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Hand Off')
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_80620/3304657001.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(plot)

# %%
# Sensitivity analysis

# importing package
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

ax = plt.axes()
ax.set_facecolor("white")

# create data
exp1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_1.csv")
exp2 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_2.csv")
exp3 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score.csv")[:250]

# plot lines
plt.plot(exp1['Episode'], exp1['Score'], label = "Constant1=1 & Constant2=1.5")
plt.plot(exp3['Episode'], exp3['Score'], label = "Constant1=2 & Constant2=1.5")
plt.plot(exp2['Episode'], exp2['Score'], label = "Constant1=2 & Constant2=0.5")

# plt.legend()
plt.ylabel('Score')
plt.xlabel('Episode')
plt.title('Training scores with different constants')
plt.ylim((-1000,5000))
plt.legend()
plt.show()

# %%
# Sensitivity analysis

# importing package
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

ax = plt.axes()
ax.set_facecolor("white")

# create data
exp1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_1.csv")[:250]
exp2 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_2.csv")[:250]
exp3 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score.csv")[:250]

d = 350*np.ones(exp1.shape[0])
# plot lines
plt.plot(exp1['Episode'], exp1['Score']/d, label = "Constant1=1 & Constant2=1.5")
plt.plot(exp3['Episode'], exp3['Score']/d, label = "Constant1=2 & Constant2=1.5")
plt.plot(exp2['Episode'], exp2['Score']/d, label = "Constant1=2 & Constant2=0.5")

# plt.legend()
plt.ylabel('Score')
plt.xlabel('Episode')
plt.title('Training scores with different constants')
plt.ylim((-1,13))
plt.legend()
plt.show()

# %%
exp1 = np.array(pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_1.csv"))
d = 350*np.ones(exp1.shape[0])
exp1[:, 1]/d
# Out:
# array([ 8.51292930e-02, -1.27550377e-01,  2.68307600e-01, -1.49852218e-01,
#         2.76397716e+00, -3.54540345e-01, -3.35906931e-01, -3.22828081e-01,
#        -3.35061524e-01,  4.51106904e+00, -2.70316979e-01,  8.71373656e-01,
#        -2.67328111e-01, -2.76538535e-01, -2.44655223e-01, -2.94699376e-01,
#        -2.81292799e-01, -2.57362648e-01, -2.55169846e-01, -2.42583361e-01,
#        -7.82354569e-02,  2.36567735e-03, -2.51359905e-01, -2.71830454e-01,
#        -3.02976855e-01, -2.97485833e-01, -2.81979579e-01, -2.04979902e-01,
#        -1.01782696e-01,  5.32111430e-01,  1.42169466e-01,  3.16308145e-01,
#        -1.36341813e-02, -1.02521690e-02,  6.39271133e-01,  5.91068301e-01,
#         5.07292855e-01,  1.35783685e+00, -1.34061703e-01,  7.01422149e+00,
#        -1.92983830e-01, -1.92147736e-01,  3.53595736e-01, -2.48156910e-01,
#        -2.14429973e-01, -2.56040534e-01,  6.42691040e-01, -2.29128999e-01,
# ...

# %%
d
# Out:
# array([350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
#        350., 350., 350., 350., 350., 350., 350., 350., 350., 350., 350.,
# ...

# %%
# Sensitivity analysis

# importing package
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

ax = plt.axes()
ax.set_facecolor("white")

# create data
exp1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_3.csv")
exp2 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_4.csv")
exp3 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_3.csv")

# plot lines
plt.plot(exp1['Episode'], exp1['Score'], label = "Constant1=3 & Constant2=1.5")
plt.plot(exp3['Episode'], exp3['Score'], label = "Constant1=2 & Constant2=1.5")
plt.plot(exp2['Episode'], exp2['Score'], label = "Constant1=2 & Constant2=0.5")

# plt.legend()
plt.ylabel('Score')
plt.xlabel('Episode')
plt.title('Training scores with different constants')
plt.ylim((-1,15))
plt.legend()
plt.show()

# %%
sum(exp2['Score'])/len(exp2['Score']), sum(exp3['Score'])/len(exp3['Score'])
# Out:
# (0.7441676548402337, 0.753406993559129)

# %%
# importing package
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# ax = plt.axes()
# ax.set_facecolor("white")
#
# create data
exp1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_3.csv")
exp2 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_4.csv")
exp3 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_5.csv")

# # plot lines
# plt.bar(sum(exp1['Score'])/len(exp1['Score']), label = "Constant1=1 & Constant2=1.5", height=15)
# plt.bar(sum(exp2['Score'])/len(exp2['Score']), label = "Constant1=2 & Constant2=1.5", height=15)
# plt.bar(sum(exp3['Score'])/len(exp3['Score']), label = "Constant1=0.5 & Constant2=0.5", height=15)
#
# # plt.legend()
# plt.ylabel('Score')
# plt.xlabel('Episode')
# plt.title('Training scores with different constants')
# plt.ylim((-1,15))
# plt.legend()
# plt.show()



# creating the dataset
data = {"Constant1=1 & Constant2=1.5":sum(exp1['Score'])/len(exp1['Score']), "Constant1=2 & Constant2=1.5":sum(exp2['Score'])/len(exp2['Score']), "Constant1=0.5 & Constant2=0.5":sum(exp3['Score'])/len(exp3['Score'])}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)

plt.xlabel("Combination")
plt.ylabel("Mean Score")
plt.show()

# %%
list(exp3['Score'])
# Out:
# [-0.0652327590786166,
#  -0.2672073068356986,
#  0.0947617213460028,
#  -0.3140760951736167,
#  1.639641341201927,
#  0.7320577953687963,
#  -0.5135824578997082,
#  -0.4546622465881884,
#  -0.2087808796198332,
#  -0.4758070220775672,
#  0.1356093167586498,
#  -0.2645418161932206,
#  -0.4781609620455205,
#  -0.0989605491950144,
#  -0.2676687149138271,
#  -0.3689216504138988,
#  -0.4280813698104678,
#  0.2166390674807935,
#  1.846023697821406,
#  -0.4818952622929708,
#  0.7302113187055473,
#  -0.424547659073807,
#  -0.2139293850353231,
#  -0.5551310423952598,
#  -0.1939185082576362,
#  -0.5779922311397742,
#  -0.4524728563927325,
#  -0.39623252767072,
#  1.8381864124159424,
#  0.6102519629150954,
#  -0.085871174882008,
#  -0.3440564059387913,
#  -0.0767812193045243,
#  -0.3718434094526145,
#  -128.32196655545616,
#  -0.2416548636196497,
#  0.0043913068065052,
#  -0.0646161431695334,
#  0.6204650419871632,
#  -0.4965275980389467,
#  -0.5508336134686765,
#  -0.5027200737964751,
# ...

# %%
sum(list(exp3['Score'])), sum(list(exp2['Score'])), sum(list(exp1['Score']))
# Out:
# (-157.55537381425734, -21.399027192355625, -24.783736678858332)

# %%
# importing package
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# create data
exp1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_1.csv")
exp2 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_2.csv")
exp3 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score.csv")[:250]
d = 350*np.ones(exp3.shape[0])
# plot lines
plt.plot(exp3['Episode'], exp3['Score']/350)

# plt.legend()
plt.ylabel('Score')
plt.xlabel('Episode')
plt.title('Training scores')
# plt.ylim((-1000,3500))
plt.legend()
plt.show()
# Out:
# /var/folders/4n/kpf0zc5x6v98_b_fkr0d94640000gn/T/ipykernel_74655/561773123.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams['axes.facecolor'] = 'white'
# create data
exp1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_1.csv")
exp2 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score_experiment_2.csv")
exp3 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_episode_score.csv")[:250]
d = 350*np.ones(exp3.shape[0])
# plot lines
plt.figure(figsize=(10,10))
plt.plot(exp3['Episode'], (exp3['Score']/350), color='tab:cyan', linewidth=2)

# === Plot Reward Curve ===
plt.title("Highest Reward per Episode")
plt.xlabel("Episode")
plt.ylabel("Highest Reward")

plt.ylim((-1,11))
plt.grid(color='darkgray', linestyle='dashed', linewidth = "0.5")
plt.savefig('classical.png', dpi=1000)

# %%
import math
# cm1 = mcol.LinearSegmentedColormap.from_list("MyCmapName",["r","b"])
import matplotlib.pyplot as plt
plt.rcParams['axes.facecolor'] = 'white'
scores_1 = pd.read_csv("/Users/eirinipanteli/PycharmProjects/robotic-hand-simulations/Simulations/OpenDoor/PPO_test_highest_reward.csv").squeeze()
# ax = plt.axes()
# ax.set_facecolor("white")
c = np.array(range(1, 11))
plt.plot(c, scores_1)
# plot = plt.scatter(c, scores_1, s= 50, c = scores_1, cmap='rainbow_r')
# plt.colorbar(plot)
# plt.grid(True, 'both')
# plt.axhline(y=np.nanmean(scores_1), color='red', linestyle='--')
# plt.ylim((-1,11))
# plt.grid(False)

plt.ylabel('score')
plt.xlabel('episodes')
plt.title('Test scores of Open Door using PPO')

plt.show()
